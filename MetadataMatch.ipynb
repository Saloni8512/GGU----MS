# %% [markdown]
# Takes the metadata dictionary as well as the file of found terms + context.
# Matches the sentences found terms with metadata terms.
# Outputs possible metadata field matches for the given sentence

# %%
import pandas as pd

# %%
df_sentence_keywords = pd.read_csv('C:\\Users\\Hello\\Desktop\\metric_stream\\v0.02\\metadata_match\\search_outputJune08.csv')
df_sentence_keywords.head()
# Out:
#    Unnamed: 0   Category Original_Keyword Searched_Keyword  sentence_number  \
# 0           0       Time             date             date                0
# 1           1  Agreement        agreement        agreement                0
# 2           2      Legal              law              law                0
# 3           3       Time             term        condition                1
# 4           4       Time             term             term                1
#
#                                                 Text  \
# 0   DocuSign Envelope ID: F3F9AB55-4121-49E9-BE97...
# 1   DocuSign Envelope ID: F3F9AB55-4121-49E9-BE97...
# 2   DocuSign Envelope ID: F3F9AB55-4121-49E9-BE97...
# 3  Europa , 18 P.E. La Moraleja 28108 Alcobendas ...
# 4  Europa , 18 P.E. La Moraleja 28108 Alcobendas ...
#
#                                       Secondary_Term  \
# 0  ['effective', 'notice', 'subscription', 'term'...
# 1                                                 []
# ...

# %%
#inputs metadata dictionary
#sentence found keyword dataframe
#iterate through sentence dataframe
# look at the combined terminology list of original_keyword and seondary_term
# see if metadata search temrs are contained in the list
# if all terms are in the sentence term list, then add the associated metadata term to the row as possible match

def combine_keyword_list(df_keyword):
    
    complete_term_list = []
    
    for i,j in df_keyword.iterrows():
        secondary_term_tolist = eval(j['Secondary_Term'])
        original_keyword_string = str(j['Original_Keyword'])
        
        #print(type(original_keyword_string))
        
        #print(secondary_term_tolist)
        secondary_term_tolist.append(original_keyword_string)
        complete_terms = secondary_term_tolist
        
        complete_term_list.append(complete_terms)
        
    df_keyword['Complete_Term_List'] = complete_term_list
    
    return df_keyword

##test
#combine_keyword_list(df_sentence_keywords)

# %%
df_complete_keyword = combine_keyword_list(df_sentence_keywords)

# %%
# #result =  all(elem in list1  for elem in list2)
# # r is the big list. p and q are 2nd and small list

# p = ['a','b','c']
# q = ['d','e','f']
# r = ['a','b','c','d','e']

# all(elem in r for elem in q)

# %%
metadata_category_dic = \
{'99.8': ['Value'],'99.9': ['Value'],'99.99': ['Value'],\
 '12 hours': ['Time', 'Hours'],'15 days': ['Time', 'Days'],'24 hours': ['Time', 'Hours/days'],\
 '30 days': ['Time', 'Hours/days'],'48 hours': ['Time', 'Hours/Days'],\
 'Account Owner': ['Person', 'Name'],\
 'Agreement Type: MSA, Order Form (SBD), SOW, CR, Work Order, amendments': \
 ['Agreement','Amendments'],\
 'Annual Renewal Value': ['Financial', 'Value'],\
 'Auto fee increase (Y/N)': ['Fee', 'Value'],\
 'Auto renew (Y/N)': ['Time', 'String'],\
 'backup': ['Agreement', 'backup'],\
 'Billing Address': ['Address', 'Billing'],\
 'breach': ['Agreement', 'Breach'],\
 'Churn ACV': ['Agreement', 'Churn/AVC'],\
 'Churn Effective Date': ['Time', 'Date'],\
 'Churn Notification Date': ['Time', 'Date'],\
 'Churn Type (What is being churned)- text': ['Agreement', 'churn'],\
 'Client Consent required to assign - Y/N': ['Person', 'Name/ Yes or No'],\
 'Client Name': ['Person', 'Name'],\
 'Cloud Application SKU': ['Product', 'SKU'],\
 'Cloud Fee': ['Fee', 'Value'],\
 'Contract Term- 1 year, multiple years, optional years': ['Legal'],\
 'Contractual relationship (map)- P.O, EULAs, notice cancelation letters, NDA’s, termination letters': ['Legal',\
  'contract'],\
 'Corporate Address': ['Address', 'Contract'],\
 'Currency': ['Financial', 'Corporate'],\
 'Customer Corporate Address': ['Address', 'Value'],\
 'Customer Legal Contact for notices': ['Legal', 'Customer'],\
 'Customer Legal Contact for notices email': ['Legal', 'Contract'],\
 'Effective Date': ['Time', 'Contact'],\
 'Escrow Y/N': ['Financial', 'Date'],\
 'Fully Executed Date': ['Time', 'escrow'],\
 'Governing Law': ['Legal', 'Date'],\
 'Invoice billing date for renewals-- period/days (Days we can bill prior to renewal term start)': ['Financial',\
  'Contract/Law'],\
 'License Fee': ['Fee', 'Date'],\
 'License Type': ['Product', 'Value'],\
 'licensed user count': ['Product', 'License'],\
 'licensed users': ['Product', 'License'],\
 'Limitation of liability (Limited—if so X what), if unlimited mark': ['Legal',\
  'Person/Value'],\
 'Maximum users': ['Product', 'Contract'],\
 'Metrictream GS Operation Contact': ['Person', 'Value'],\
 'Nonstandard indemnity': ['Legal', 'Name/Phone#'],\
 'Opportunity Owner': ['Person'],\
 'Other Order Form Terms': ['Legal', 'Name'],\
 'Partner Fee %--Text field': ['Fee'],\
 'Partner Name/Reseller': ['Person', 'Value'],\
 'Payment term': ['Financial', 'Name'],\
 'Penalty/Credit for SLA (Y/N)': ['Legal', 'Value'],\
 'Platform Fee': ['Fee', 'penalty'],\
 'Product SKU Version (Version)': ['Product', 'Value'],\
 'Renegotiation comments/terms': ['Legal', 'SKU'],\
 'Renewal Date': ['Time', 'Comments'],\
 'Renewal Notice Period/Date': ['Time', 'Date'],\
 'Renewal Price Increase': ['Financial', 'Date'],\
 'Renewal Term': ['Time', 'Value'],\
 'SLA': ['Legal', 'Term'],\
 'Subscription Beginning Date': ['Time'],\
 'Support Fee': ['Fee', 'Date'],\
 'Term End Date': ['Time', 'Value'],\
 'Term Start Date': ['Time', 'Date'],\
 'Termination for convenience- notice period': ['Legal', 'Date'],\
 'Third party product fee': ['Fee', 'Contract'],\
 'total users': ['Product', 'Value'],\
 'Type of Support': ['Agreement', 'Person/Value'],\
 'uptime': ['Agreement/Time', 'Day/Date']}\

# %%
metadata_term_dic = \
{'99.8': ['99'],\
 '99.9': ['99'],\
 '99.99': ['99'],\
 '12 hours': ['hours', '12'],\
 '15 days': ['days', '15'],\
 '24 hours': ['hours', '24'],\
 '30 days': ['days', '30'],\
 '48 hours': ['hours', '48'],\
 'Account Owner': ['owner', 'account'],\
 'Agreement Type: MSA, Order Form (SBD), SOW, CR, Work Order, amendments': ['agreement',\
  'type'],\
 'Annual Renewal Value': ['value', 'renewal', 'annual'],\
 'Auto fee increase (Y/N)': ['fee', 'automatically'],\
 'Auto renew (Y/N)': ['renewal', 'automatically'],\
 'backup': ['backup'],\
 'Billing Address': ['address', 'billing'],\
 'breach': ['breach'],\
 'Churn ACV': ['churn', 'acv'],\
 'Churn Effective Date': ['date', 'churn', 'effective'],\
 'Churn Notification Date': ['date', 'churn', 'notification'],\
 'Churn Type (What is being churned)- text': ['churn', 'type'],\
 'Client Consent required to assign - Y/N': ['client', 'consent'],\
 'Client Name': ['client', 'name'],\
 'Cloud Application SKU': ['SKU', 'cloud', 'application'],\
 'Cloud Fee': ['fee', 'cloud'],\
 'Contract Term- 1 year, multiple years, optional years': ['contract', 'term'],\
 'Contractual relationship (map)- P.O, EULAs, notice cancelation letters, NDA’s, termination letters': ['contract',\
  'relationship'],\
 'Corporate Address': ['address', 'corporate'],\
 'Currency': ['currency'],\
 'Customer Corporate Address': ['address', 'corporate', 'customer'],\
 'Customer Legal Contact for notices': ['legal', 'customer', 'contact'],\
 'Customer Legal Contact for notices email': ['legal', 'contact', 'email'],\
 'Effective Date': ['date', 'effective'],\
 'Escrow Y/N': ['escrow'],\
 'Fully Executed Date': ['date', 'executed', 'fully'],\
 'Governing Law': ['law', 'governing'],\
 'Invoice billing date for renewals-- period/days (Days we can bill prior to renewal term start)': ['renewal',\
  'date','invoice'],\
 'License Fee': ['fee', 'license'],\
 'License Type': ['license', 'type'],\
 'licensed user count': ['User', 'license', 'count'],\
 'licensed users': ['user', 'license', 'type'],\
 'Limitation of liability (Limited—if so X what), if unlimited mark': ['liability','limitation'],\
 'Maximum users': ['user', 'maximum'],\
 'Metrictream GS Operation Contact': ['contact', 'operation', 'metricstream'],\
 'Nonstandard indemnity': ['indemnity', 'nonstandard'],\
 'Opportunity Owner': ['owner', 'opportunity'],\
 'Other Order Form Terms': ['term', 'order', 'form'],\
 'Partner Fee %--Text field': ['fee', 'partner'],\
 'Partner Name/Reseller': ['name', 'partner'],\
 'Payment term': ['term', 'payment'],\
 'Penalty/Credit for SLA (Y/N)': ['penalty', 'sla'],\
 'Platform Fee': ['fee', 'platform'],\
 'Product SKU Version (Version)': ['SKU', 'product', 'version'],\
 'Renegotiation comments/terms': ['renegotiation', 'comments', 'terms'],\
 'Renewal Date': ['date', 'renewal'],\
 'Renewal Notice Period/Date': ['date', 'notice', 'renewal'],\
 'Renewal Price Increase': ['price', 'renewal', 'increase'],\
 'Renewal Term': ['term', 'renewal'],\
 'SLA': ['SLA'],\
 'Subscription Beginning Date': ['date', 'subscription', 'beginning'],\
 'Support Fee': ['fee', 'support'],\
 'Term End Date': ['date', 'term', 'end'],\
 'Term Start Date': ['date', 'term', 'start'],\
 'Termination for convenience- notice period': ['termination','convenience','notice'],\
 'Third party product fee': ['fee', 'product', 'party'],\
 'total users': ['user', 'total'],\
 'Type of Support': ['support', 'type'],\
 'uptime': ['uptime']}

# %%
# check each row to see if metadata fields are in the keywords list
# create new column in dataframe that shows all possible metadata matches

def metadata_match(df_keyword, dic_metadata, dic_category):
    
    metadata_matches_outer = []
    category1_match_outer = []
    category2_match_outer = []
    
    for i,j in df_keyword.iterrows():
        
        metadata_matches_inner = []
        category1_match_inner = []
        category2_match_inner = []
                   
        term_list = j['Complete_Term_List']
        
        for key in dic_metadata:
            
            if all(elem in term_list for elem in dic_metadata[key]):
                metadata_matches_inner.append(key)
                category1_match_inner.append(dic_category[key][0])
                   
                try: 
                    category2_match_inner.append(dic_category[key][1])
                except:
                    category2_match_inner.append(None)
                   
            else:
                pass
            
        metadata_matches_outer.append(metadata_matches_inner)
        category1_match_outer.append(list(set(category1_match_inner)))
        category2_match_outer.append(list(set(category2_match_inner)))   
    
    df_keyword['Metadata_Matches'] = metadata_matches_outer
    df_keyword['Metadata_Category'] = category1_match_outer
    df_keyword['Metadata_SubCategory'] = category2_match_outer
                   
    return df_keyword

# %%
df0_metadatamatch = metadata_match(df_complete_keyword, metadata_term_dic, metadata_category_dic)
df0_metadatamatch.to_csv('C:\\Users\\Hello\\Desktop\\metric_stream\\v0.02\\metadata_match\\metadataoutput_June08.csv')
